# %%
import requests 
from bs4 import BeautifulSoup

# %%
def getdata(url): 
	r = requests.get(url) 
	return r.text

# %%
htmldata = getdata("https://covid-19tracker.milkeninstitute.org/") 
soup = BeautifulSoup(htmldata, 'html.parser') 
result = str(soup.find_all("div", class_="is_h5-2 is_developer w-richtext"))
print(str(result))
# Out:
# [<div class="is_h5-2 is_developer w-richtext">Alexion Pharmaceuticals. TACTIC-R trial </div>, <div class="is_h5-2 is_developer w-richtext">Assistance Publique - Hopitaux de Paris (Phase II); Alexion (Expanded Access Protocols)</div>, <div class="is_h5-2 is_developer w-richtext">AstraZeneca; ACCORD trial </div>, <div class="is_h5-2 is_developer w-richtext">BioCon/Equilium </div>, <div class="is_h5-2 is_developer w-richtext">Celltrion</div>, <div class="is_h5-2 is_developer w-richtext">Celltrion/ University of Oxford/ University Hospitals Birmingham (CATALYST trial)</div>, <div class="is_h5-2 is_developer w-richtext">Cerecor</div>, <div class="is_h5-2 is_developer w-richtext">CytoDyn</div>, <div class="is_h5-2 is_developer w-richtext">EUSA Pharma / The Papa Giovanni XXII Hospital; University Hospital, Ghent; Fundacion Clinic per a la Recerca BiomÃ©dica</div>, <div class="is_h5-2 is_developer w-richtext">Edesa Biotech/ Light Chain Bioscience (NovImmune)</div>, <div class="is_h5-2 is_developer w-richtext">Eli Lilly</div>, <div class="is_h5-2 is_developer w-richtext">Eli Lilly/AbCellera (NIH Vaccines Research Center)/Takeda</div>, <div class="is_h5-2 is_developer w-richtext">GSK</div>, <div class="is_h5-2 is_developer w-richtext">Humanigen Inc./ Catalent Biologics</div>, <div class="is_h5-2 is_developer w-richtext">I-Mab Biopharma</div>, <div class="is_h5-2 is_developer w-richtext">Implicit Bioscience</div>, <div class="is_h5-2 is_developer w-richtext">InflaRx N.V.</div>, <div class="is_h5-2 is_developer w-richtext">Junshi Biosciences/ Eli Lilly/ Lonza/ AbCellera</div>, <div class="is_h5-2 is_developer w-richtext">Kamada/ Kedrion Biopharma/ Columbia University Irving Medical Center</div>, <div class="is_h5-2 is_developer w-richtext">Kiniksa/ Cleveland Clinic/ Ospedale San Raffaele</div>, <div class="is_h5-2 is_developer w-richtext">Multiple global research sponsors, including: New York State Department of Health; Johns Hopkins University; the Feinstein Institutes; RECOVERY trial</div>, <div class="is_h5-2 is_developer w-richtext">Multiple global research sponsors; Octapharma USA/ Sharp Memorial Hospital; Grifols</div>, <div class="is_h5-2 is_developer w-richtext">Novartis; other research sponsors
# </div>, <div class="is_h5-2 is_developer w-richtext">Numerous trials with Chinese research sponsors</div>, <div class="is_h5-2 is_developer w-richtext">Numerous trials with Chinese research sponsors; Roche</div>, <div class="is_h5-2 is_developer w-richtext">Numerous trials with global research sponsors; Roche; REMAP-CAP; RECOVERY</div>, <div class="is_h5-2 is_developer w-richtext">Regeneron/ NIAID</div>, <div class="is_h5-2 is_developer w-richtext">Roivant Sciences</div>, <div class="is_h5-2 is_developer w-richtext">Staidson/ Pivotal</div>, <div class="is_h5-2 is_developer w-richtext">Swedish Orphan Biovitrum</div>, <div class="is_h5-2 is_developer w-richtext">Tang-Du Hospital</div>, <div class="is_h5-2 is_developer w-richtext">Tychan/ SingHealth Investigational Medicine Unit</div>, <div class="is_h5-2 is_developer w-richtext">University of Hong Kong (BMS)</div>, <div class="is_h5-2 is_developer w-richtext">Various global research sponsors/ Grifols/ Emergent BioSolutions, CSL Behring and Takeda</div>, <div class="is_h5-2 is_developer w-richtext">Vir Biotechnology/ GSK/ Samsung/ WuXi Biologics/ Biogen</div>, <div class="is_h5-2 is_developer w-richtext">Abcore</div>, <div class="is_h5-2 is_developer w-richtext">Ablexis / AlivaMab Discovery Services / Berkeley Lights Collaborate</div>, <div class="is_h5-2 is_developer w-richtext">Adagio Therapeutics</div>, <div class="is_h5-2 is_developer w-richtext">Alliance - Proteona/ NMI/ NUS Enterprise/10X Genomics/ NovogeneAIT/ Twist Bioscience/ University Hospitals/ German Cancer Research Center, Heidelberg University Hospital/ TÃ¼bingen University Hospital/ NovogeneAIT</div>, <div class="is_h5-2 is_developer w-richtext">Amgen/ Adaptive Biotechnologies</div>, <div class="is_h5-2 is_developer w-richtext">AstraZeneca / US Army Medical Research Institute of Infectious Diseases (USAMRIID)/ University of Maryland School of Medicine</div>, <div class="is_h5-2 is_developer w-richtext">Atreca / BeiGene / IGM Biosciences/ Singlomics</div>, <div class="is_h5-2 is_developer w-richtext">CSL Behring / SAb Biotherapeutics</div>, <div class="is_h5-2 is_developer w-richtext">CSL Behring Australia</div>, <div class="is_h5-2 is_developer w-richtext">Celltrion</div>, <div class="is_h5-2 is_developer w-richtext">Centivax (Distributed Bio)</div>, <div class="is_h5-2 is_developer w-richtext">Chelsea and Westminster Hospital, Imperial College London</div>, <div class="is_h5-2 is_developer w-richtext">CoVIg-19 Plasma Alliance (Takeda, CSL Behring, Biotest AG, Bio Products Laboratory, LFB, and Octapharma, ADMA Biologics, BioPharma Plasma, GC Pharma, Sanquin)/Gates Foundation/ NIAID/ Microsoft</div>, <div class="is_h5-2 is_developer w-richtext">Cologne University Hospital/ German Center for Infection Research/ Boehringer Ingelheim</div>, <div class="is_h5-2 is_developer w-richtext">Columbia University Irving Medical Center; IAVI and Serum  Research Institute India</div>, <div class="is_h5-2 is_developer w-richtext">Costa Rican Social Security Fund (CCSS)/ The University of Costa Rica (UCR)/ Clodomiro Picado Institute</div>, <div class="is_h5-2 is_developer w-richtext">Edesa Biotech / Light Chain Bioscience (NovImmune)</div>, <div class="is_h5-2 is_developer w-richtext">Eli Lilly/ Sanford Burnham Prebys Medical Discovery Institute</div>, <div class="is_h5-2 is_developer w-richtext">Emergent BioSolutions</div>, <div class="is_h5-2 is_developer w-richtext">Emergent BioSolutions/ National Institute of Allergy and Infectious Diseases (NIAID)/ Mt Sinai Health System/ ImmunoTek Bio Centers</div>, <div class="is_h5-2 is_developer w-richtext">Fab'entech</div>, <div class="is_h5-2 is_developer w-richtext">FairJourney Biologics / Iontas</div>, <div class="is_h5-2 is_developer w-richtext">GC Pharma/ Korea National Institute of Health</div>, <div class="is_h5-2 is_developer w-richtext">Generation Bio/ Vir Biotechnology</div>, <div class="is_h5-2 is_developer w-richtext">GigaGen</div>, <div class="is_h5-2 is_developer w-richtext ...
# </div>, <div class="is_h5-2 is_developer w-richtext">BioCryst Pharmaceuticals</div>, <div class="is_h5-2 is_developer w-richtext">Bukwang Pharm</div>, <div class="is_h5-2 is_developer w-richtext">Fujifilm Toyama Chemical/ Zhejiang Hisun Pharmaceuticals/ numerous trials with global research sponsors/ Brigham and Women's Hospital, Massachusetts General Hospital, and the University of Massachusetts Medical School/ Glenmark Pharmaceuticals</div>, <div class="is_h5-2 is_developer w-richtext">Gilead; World Health Organization SOLIDARITY trial; National Institute of Allergy and Infectious Diseases (NIAID)'s Adaptive COVID-19 Treatment Trial; Feinstein Institutes; I-SPY COVID</div>, <div class="is_h5-2 is_developer w-richtext">Global hospital testing (AbbVie); World Health Organization SOLIDARITY trial (studying lopinavir/ ritonavir with and without interferon beta); University of Oxford RECOVERY trial; REMAP-CAP global trial; Univ. of College, London</div>, <div class="is_h5-2 is_developer w-richtext">Hospital
#   Universitario Infanta Leonor/ Viiv Healthcare; Hospital General de MÃ©xico Dr.
#   Eduardo Liceaga; Rhode Island Hospital</div>, <div class="is_h5-2 is_developer w-richtext">Hospital do Coracao</div>, <div class="is_h5-2 is_developer w-richtext">Multiple global research sponsors
# </div>, <div class="is_h5-2 is_developer w-richtext">Multiple global research sponsors
# </div>, <div class="is_h5-2 is_developer w-richtext">NeuroActiva</div>, <div class="is_h5-2 is_developer w-richtext">Plan Nacional sobre el Sida
# </div>, <div class="is_h5-2 is_developer w-richtext">Ridgeback Biotherapeutics / Drug Innovation Ventures at Emory (DRIVE)/ Merck</div>, <div class="is_h5-2 is_developer w-richtext">Roche; REMAP-CAP global trial</div>, <div class="is_h5-2 is_developer w-richtext">Various  global research sponsors/University of Liverpool/Obafemi Awolowo University</div>, <div class="is_h5-2 is_developer w-richtext">Various global research sponsors</div>, <div class="is_h5-2 is_developer w-richtext">Agastiya Biotech</div>, <div class="is_h5-2 is_developer w-richtext">Anivive
#   Lifesciences</div>, <div class="is_h5-2 is_developer w-richtext">Cidara Therapeutics</div>, <div class="is_h5-2 is_developer w-richtext">Cocrystal Pharma</div>, <div class="is_h5-2 is_developer w-richtext">ISR Immune System Regulation</div>, <div class="is_h5-2 is_developer w-richtext">National Institute of Allergy and Infectious Disease (NIAID)/University of Minnesota</div>, <div class="is_h5-2 is_developer w-richtext">SCORE consortium (universities of Aix-Marseille, Leuven, Utrecht, Bern, and Lubeck), the Helmholtz Centre for Infection Research, and Janssen Pharmaceutica NV</div>, <div class="is_h5-2 is_developer w-richtext">Selva TherapeuticsÂ </div>, <div class="is_h5-2 is_developer w-richtext">Stanford
#   University/ US Department of Energy's Lawrence Berkeley National Laboratory</div>, <div class="is_h5-2 is_developer w-richtext">ViralClear Pharmaceuticals</div>, <div class="is_h5-2 is_developer w-richtext">AgenTus Therapeutics (Agenus)Â </div>, <div class="is_h5-2 is_developer w-richtext">Aspire Health Science</div>, <div class="is_h5-2 is_developer w-richtext">Athersys / The University of Texas Health Science Center at Houston</div>, <div class="is_h5-2 is_developer w-richtext">Caladrius Biosciences</div>, <div class="is_h5-2 is_developer w-richtext">Capricor Inc.</div>, <div class="is_h5-2 is_developer w-richtext">Cellenkos</div>, <div class="is_h5-2 is_developer w-richtext">Celltex</div>, <div class="is_h5-2 is_developer w-richtext">Celularity/ Lung Biotechnology PBC/ California Institute for Regnerative Medicine (CIRM)</div>, <div class="is_h5-2 is_developer w-richtext">Cynata Therapeutics</div>, <div class="is_h5-2 is_developer w-richtext">Daewoong</div>, <div class="is_h5-2 is_developer w-richtext">Enlivex Therapeutics</div>, <div class="is_h5-2 is_developer w-richtext">Hope Biosciences/Daewoong Pharmaceutical Co. LTD/ Other global research sponsors</div>, <div class="is_h5-2 is_developer w-richtext">Lattice Biologics</div>, <div class="is_h5-2 is_developer w-richtext">Mesoblast/ Cardiothoracic Surgical Trials Network</div>, <div class="is_h5-2 is_developer w-richtext">Naturecell Co. LTD</div>, <div class="is_h5-2 is_developer w-richtext">Numerous trials with global research sponsors/ MD Anderson Cancer Center</div>, <div class="is_h5-2 is_developer w-richtext">Pluristem Therapeutics/ BIH Center for Regenerative Therapy/ Berlin Center for Advanced Therapies</div>, <div class="is_h5-2 is_developer w-richtext">Red de Terapia Celular (TerCel)</div>, <div class="is_h5-2 is_developer w-richtext">Therapeutic Solutions International</div>, <div class="is_h5-2 is_developer w-richtext">Trustem Cell Therapy</div>, <div class="is_h5-2 is_developer w-richtext">Vitro Biopharma/ Global Institute of Stem Cell Therapy and Research</div>, <div class="is_h5-2 is_developer w-richtext">AgeX
#   Therapeutics/ ImStem Biotechnology</div>, <div class="is_h5-2 is_developer w-richtext">AlloVir / Baylor College of Medicine</div>, <div class="is_h5-2 is_developer w-richtext">Baylx, Inc.Â </div>, <div class="is_h5-2 is_developer w-richtext">BioCardia</div>, <div class="is_h5-2 is_developer w-richtext">CAR-T (Shanghai) Biotechnology</div>, <div class="is_h5-2 is_developer w-richtext">Citius/Novellus</div>, <div class="is_h5-2 is_developer w-richtext">Duke-NUS Medical School; various hospitals (Singapore)</div>, <div class="is_h5-2 is_developer w-richtext">GC LabCell / KLEO Pharmaceuticals</div>, <div class="is_h5-2 is_developer w-richtext">ImmunityBio / NantKwest</div>, <div class="is_h5-2 is_developer w-richtext">ImmunityBio / NantKwest / Be The Match BioTherapies</div>, <div class="is_h5-2 is_developer w-richtext">Kangstem Biotech</div>, <div class="is_h5-2 is_developer w-richtext">Regeneris Medical</div>, <div class="is_h5-2 is_developer w-richtext">SMSbiotech</div>, <div class="is_h5-2 is_developer w-richtext">Sentien Biotechnologies</div>, <div class="is_h5-2 is_developer w-richtext">ALung Technologies</div>, <div class="is_h5-2 is_developer w-richtext">Abiomed</div>, <div class="is_h5-2 is_developer w-richtext">Baxter</div>, <div class="is_h5-2 is_developer w-richtext">Bellerophon; Ohio State University Wexner Medical Center </div>, <div class="is_h5-2 is_developer w-richtext">Beyond Air Ltd</div>, <div class="is_h5-2 is_developer w-richtext">CytoSorbents Corporation</div>, <div class="is_h5-2 is_developer w-richtext">ExThera Medical</div>, <div class="is_h5-2 is_developer w-richtext">Fresenius Medical</div>, <div class="is_h5-2 is_developer w-richtext">Terumo BCT Inc / Marker Therapeutics AG</div>, <div class="is_h5-2 is_developer w-richtext">electroCore</div>, <div class="is_h5-2 is_developer w-richtext">Mateon Therapeutics</div>, <div class="is_h5-2 is_developer w-richtext">AIM ImmunoTech/ National Institute of Infectious Diseases in Japan/ Roswell Park Comprehensive Cancer Center</div>, <div class="is_h5-2 is_developer w-richtext">Neurimmune/ Ethris</div>, <div class="is_h5-2 is_developer w-richtext">Sarepta Therapeutics / US Army Medical Research Institute of Infectious Diseases (USAMRIID)</div>, <div class="is_h5-2 is_developer w-richtext">Sirnaomics</div>, <div class="is_h5-2 is_developer w-richtext">Vir Biotech / Alnylam Pharmaceuticals</div>, <div class="is_h5-2 is_developer w-richtext">Anixa Biosciences / OntoChem</div>, <div class="is_h5-2 is_developer w-richtext">COVID-19 Therapeutics Accelerator</div>, <div class="is_h5-2 is_developer w-richtext">Enanta Pharmaceuticals</div>, <div class="is_h5-2 is_developer w-richtext">Exscalate4Cov,
#   public-private consortium</div>, <div class="is_h5-2 is_developer w-richtext">Healx</div>, <div class="is_h5-2 is_developer w-richtext">Janssen Pharmaceutical Companies</div>, <div class="is_h5-2 is_developer w-richtext">Materia Medica/Cyclica/Manin</div>, <div class="is_h5-2 is_developer w-richtext">Merck</div>, <div class="is_h5-2 is_developer w-richtext">Novartis</div>, <div class="is_h5-2 is_developer w-richtext">Nuritas</div>, <div class="is_h5-2 is_developer w-richtext">Pfizer</div>, <div class="is_h5-2 is_developer w-richtext">Quantitative Biosciences Institute Coronavirus Research Group</div>, <div class="is_h5-2 is_developer w-richtext">Queens University Belfast</div>, <div class="is_h5-2 is_developer w-richtext">Sanford Burnham Prebys Medical Discovery Institute, the University of Hong Kong, Scripps Research, UC San Diego School of Medicine, the Icahn School of Medicine at Mount Sinai and UCLA</div>, <div class="is_h5-2 is_developer w-richtext">Shionogi / Hokkaido University Research Center for Zoonosis Control</div>, <div class="is_h5-2 is_developer w-richtext">Southwest Research Institute</div>, <div class="is_h5-2 is_developer w-richtext">Takeda</div>, <div class="is_h5-2 is_developer w-richtext">The Castleman Disease Collaborative Network and the Center for Study &amp; Treatment of Inflammatory Lymphadenopathies</div>, <div class="is_h5-2 is_developer w-richtext">Vanda Pharmaceuticals / University of Illinois at Chicago</div>, <div class="is_h5-2 is_developer w-richtext">Vir Biotechnology / GSK</div>, <div class="is_h5-2 is_developer w-richtext">Wyss
#   Institute</div>, <div class="is_h5-2 is_developer w-richtext"> I-SPY COVID Trial (Takeda)</div>, <div class="is_h5-2 is_developer w-richtext">4D Pharma</div>, <div class="is_h5-2 is_developer w-richtext">ACCORD trial; University Hospital, Ghent/UCB PharmaÂ </div>, <div class="is_h5-2 is_developer w-richtext">AI Therapeutics/ Yale University  </div>, <div class="is_h5-2 is_developer w-richtext">ARMS Pharmaceutical / UH Cleveland Medical Center / Case Western Reserve University</div>, <div class="is_h5-2 is_developer w-richtext">Aarhus University</div>, <div class="is_h5-2 is_developer w-richtext">Abivax</div>, <div class="is_h5-2 is_developer w-richtext">Aldeyra Therapeutics</div>, <div class="is_h5-2 is_developer w-richtext">Aldeyra Therapeutics</div>, <div class="is_h5-2 is_developer w-richtext">Algernon Pharmaceuticals</div>, <div class="is_h5-2 is_developer w-richtext">Amarin Corp</div>, <div class="is_h5-2 is_developer w-richtext">Amgen; I-SPY COVID trial/Takeda/AbbieVie   </div>, <div class="is_h5-2 is_developer w-richtext">Apeptico/ Medical University Vienna</div>, <div class="is_h5-2 is_developer w-richtext">Applied
#   Biology/ Brown University/ Corpometria Institute</div>, <div class="is_h5-2 is_developer w-richtext">Applied Therapeutics/ numerous New York City hospitals</div>, <div class="is_h5-2 is_developer w-richtext">Arch Biopartners</div>, <div class="is_h5-2 is_developer w-richtext">AstraZeneca/ Saint Luke's Mid America Heart Institute; Cambridge University Hospitals NHS Foundation Trust; TACTIC-E trial studying dapagliflozin + ambrisentan</div>, <div class="is_h5-2 is_developer w-richtext">AstraZeneca; ACCORD study/Rigel Pharmaceuticals</div>, <div class="is_h5-2 is_developer w-richtext">BerGenBio; ACCORD study</div>, <div class="is_h5-2 is_developer w-richtext">Beth Israel Deaconess, the University of Colorado Anschultz Medical Campus, and Denver Health (Genentech); University College London; Boehringer Ingelheim</div>, <div class="is_h5-2 is_developer w-richtext">BioAegis Therapeutics Inc.</div>, <div class="is_h5-2 is_developer w-richtext">Biohaven/ Thomas Jefferson University</div>, <div class="is_h5-2 is_developer w-richtext">Biomarck Pharmaceuticals</div>, <div class="is_h5-2 is_developer w-richtext">Blade Therapeutics</div>, <div class="is_h5-2 is_developer w-richtext">CTI Biopharma</div>, <div class="is_h5-2 is_developer w-richtext">CalciMedica</div>, <div class="is_h5-2 is_developer w-richtext">Can-Fite BioPharma</div>, <div class="is_h5-2 is_developer w-richtext">Center for Clinical Metabolic Research, Gentofte Hospital</div>, <div class="is_h5-2 is_developer w-richtext">Chimerix
# </div>, <div class="is_h5-2 is_developer w-richtext">Cyclacel Pharmaceuticals / University of Edinburgh</div>, <div class="is_h5-2 is_developer w-richtext">Cyclacel Pharmaceuticals / University of Edinburgh</div>, <div class="is_h5-2 is_developer w-richtext">Dompe farmaceutici (as part of Exscalate4CoV)</div>, <div class="is_h5-2 is_developer w-richtext">Eagle Pharmaceuticals / Amneal Pharmaceuticals / Alcami Corporation / Hackensack University Medical Center</div>, <div class="is_h5-2 is_developer w-richtext">Eiger BioPharmaceuticals, Inc./ Johns Hopkins University</div>, <div class="is_h5-2 is_developer w-richtext">Eisai </div>, <div class="is_h5-2 is_developer w-richtext">Evelo Biosciences/ Rutgers University/ Robert Wood Johnson University Hospital/ TACTIC-E trial (Cambridge University Hospitals NHS Foundation Trust)</div>, <div class="is_h5-2 is_developer w-richtext">Exvastat Ltd / Global sponsors</div>, <div class="is_h5-2 is_developer w-richtext">FSD Pharma</div>, <div class="is_h5-2 is_developer w-richtext">Faron Pharmaceuticals / REMAP-CAP global trial/ WHO SOLIDARITY trial/ various global researchers</div>, <div class="is_h5-2 is_developer w-richtext">Feinstein Institutes for Medical Research at Northwell Health/ Alchem</div>, <div class="is_h5-2 is_developer w-richtext">Fulcrum
#   Therapeutics</div>, <div class="is_h5-2 is_developer w-richtext">Genentech</div>, <div class="is_h5-2 is_developer w-richtext">Genentech</div>, <div class="is_h5-2 is_developer w-richtext">Genetic Engineering and Biotechnology Center (CIGB), Cuba</div>, <div class="is_h5-2 is_developer w-richtext">Global research sponsors</div>, <div class="is_h5-2 is_developer w-richtext">Heron Therapeutics</div>, <div class="is_h5-2 is_developer w-richtext">I-SPY COVID Trial (Aerpio Pharmaceuticals), - RESCUE Trial various academic researchers/Medical Technology Enterprise Consortium (MTEC)</div>, <div class="is_h5-2 is_developer w-richtext">I-SPY COVID Trial (Allergan); National Center for Advancing Translational Science (NCATS) Biomedical Advanced Research and Development Authority (BARDA)</div>, <div class="is_h5-2 is_developer w-richtext">Immunic, Inc./University Hospitals Coventry and Warwickshire NHS Trust</div>, <div class="is_h5-2 is_developer w-richtext">ImmunityBio/ NantKwest</div>, <div class="is_h5-2 is_developer w-richtext">Innovation Pharmaceuticals</div>, <div class="is_h5-2 is_developer w-richtext">Inotrem</div>, <div class="is_h5-2 is_developer w-richtext">Insmed Inc.</div>, <div class="is_h5-2 is_developer w-richtext">Institut National de la Sante et de la Recherche Medicale (Merck KGaA); IRCCS San Raffaele; WHO global SOLIDARITY Trial</div>, <div class="is_h5-2 is_developer w-richtext">KD Pharma / SLA Pharma</div>, <div class="is_h5-2 is_developer w-richtext">Karyopharm Therapeutics</div>, <div class="is_h5-2 is_developer w-richtext">King's College London</div>, <div class="is_h5-2 is_developer w-richtext">Kintor/ Applied Biology</div>, <div class="is_h5-2 is_developer w-richtext">Laurent Pharmaceuticals</div>, <div class="is_h5-2 is_developer w-richtext">Massachusetts General Hospital; University of British Columbia; Sanotize Research and Development</div>, <div class="is_h5-2 is_developer w-richtext">MediciNova/ Yale
# </div>, <div class="is_h5-2 is_developer w-richtext">MedinCell/ University of Utah/ Surgisphere Corp; University of Baghdad; Tanta University; other global research sponsors</div>, <div class="is_h5-2 is_developer w-richtext">Multiple global research sponsors
# </div>, <div class="is_h5-2 is_developer w-richtext">Multiple global research sponsors
# </div>, <div class="is_h5-2 is_developer w-richtext">Multiple global research sponsors, including UK SPIKE-1 trial</div>, <div class="is_h5-2 is_developer w-richtext">Multiple global research sponsors, including University of Tokyo/ National Center for Global Health and Medicine/ Ensysce Biosciences/ Institut Pasteur Korea/ Daiichi Sankyo (inhalation formulation)/ University of Edinburgh </div>, <div class="is_h5-2 is_developer w-richtext">Multiple global research sponsors; ACCORD Trial</div>, <div class="is_h5-2 is_developer w-richtext">NIH ACTIV-4 Antithrombotics/ nonprofit organizations/numerous biopharmaceutical companies</div>, <div class="is_h5-2 is_developer w-richtext">National Institute of Allergy and Infectious Disease (NIAID)'s Adaptive COVID-19 Treatment Trial; Nova Scotia Health Authority; Hospital of Prato; University of Colorado (Eli Lilly); TACTIC-R trial</div>, <div class="is_h5-2 is_developer w-richtext">NeoImmune Tech/ NIAID / University of Nebraska Medical Center</div>, <div class="is_h5-2 is_developer w-richtext">NeuroRx/ Relief Therapeutics/ Thomas Jefferson University Hospital/ NYU Langone Health/ Houston Methodist Hospital</div>, <div class="is_h5-2 is_developer w-richtext">Novartis / Incyte, numerous researchers globally</div>, <div class="is_h5-2 is_developer w-richtext">Noveome Biotherapeutics/ Singota Solutions</div>, <div class="is_h5-2 is_developer w-richtext">Noxopharm</div>, <div class="is_h5-2 is_developer w-richtext">Numerous global sponsors</div>, <div class="is_h5-2 is_developer w-richtext">Numerous research sponsors globally</div>, <div class="is_h5-2 is_developer w-richtext">Numerous research sponsors globally</div>, <div class="is_h5-2 is_developer w-richtext">Numerous trials with global research sponsors including World Health Organization SOLIDARITY trial; ORCHID trial with National Heart, Lung, and Blood Institute (NHLBI); REMAP-CAP global trial; Novartis; PRINCIPLE trial</div>, <div class="is_h5-2 is_developer w-richtext">Numerous trials with research sponsors globally; University of Oxford RECOVERY trial; REMAP-CAP global trial; Covis Pharma B.V.</div>, <div class="is_h5-2 is_developer w-richtext">OncoImmune</div>, <div class="is_h5-2 is_developer w-richtext">Organicell Regenerative Medicine</div>, <div class="is_h5-2 is_developer w-richtext">Orpheris
#   (Ashvattha Therapeutics)</div>, <div class="is_h5-2 is_developer w-richtext">PTC Therapeutics</div>, <div class="is_h5-2 is_developer w-richtext">Panoptes Pharma GmbH</div>, <div class="is_h5-2 is_developer w-richtext">Partner Therapeutics/ Singapore General Hospital/ University Hospital, Ghent</div>, <div class="is_h5-2 is_developer w-richtext">Pfizer; other global research sponsors</div>, <div class="is_h5-2 is_developer w-richtext">PharmaMar/ Boryung Pharmaceutical/ Hospitals in Spain</div>, <div class="is_h5-2 is_developer w-richtext">Pharming</div>, <div class="is_h5-2 is_developer w-richtext">PhaseBio</div>, <div class="is_h5-2 is_developer w-richtext">Pulmotect</div>, <div class="is_h5-2 is_developer w-richtext">RECOVERY trial and multiple global research sponsors</div>, <div class="is_h5-2 is_developer w-richtext">REMAP-CAP trial</div>, <div class="is_h5-2 is_developer w-richtext">REMAP-CAP trial</div>, <div class="is_h5-2 is_developer w-richtext">RedHill Biopharma
# </div>, <div class="is_h5-2 is_developer w-richtext">RedHill Biopharma/ NIAID
# </div>, <div class="is_h5-2 is_developer w-richtext">Resverlogix</div>, <div class="is_h5-2 is_developer w-richtext">Romark Laboratories; various researchers globally</div>, <div class="is_h5-2 is_developer w-richtext">SciTech Development, LLC</div>, <div class="is_h5-2 is_developer w-richtext">Sun
#   Pharmaceutical Industries Ltd</div>, <div class="is_h5-2 is_developer w-richtext">Swedish Orphan Biovitrum/ REMAP-CAP global trial/ Numerous global trial sponsors </div>, <div class="is_h5-2 is_developer w-richtext">Synairgen/ University of Southampton</div>, <div class="is_h5-2 is_developer w-richtext">Union Therapeutics/ Institute Pasteur Korea/ Daewoong Therapeutics; First Wave Bio/ANA Therapeutics</div>, <div class="is_h5-2 is_developer w-richtext">University of Alabama at Birmingham; Leading Biosciences</div>, <div class="is_h5-2 is_developer w-richtext">University of British Columbia/Apeiron Biologics</div>, <div class="is_h5-2 is_developer w-richtext">University of Hawaii (Boehringer Ingelheim); other global research sponsors</div>, <div class="is_h5-2 is_developer w-richtext">Vanda Pharmaceuticals / Feinstein Institutes for Medical Research at Northwell Health</div>, <div class="is_h5-2 is_developer w-richtext">Various global research sponsors</div>, <div class="is_h5-2 is_developer w-richtext">Various researchers globally, including University of Oxford</div>, <div class="is_h5-2 is_developer w-richtext">Various researchers worldwide, including Ashford and St Peters Hospital NHS Trust/  Guangdong Uni-Innovation Pharmaceuticals Co., Ltd./ Clear Creek Bio, LLC/BMS</div>, <div class="is_h5-2 is_developer w-richtext">Various researchers worldwide, including University College London/ The Francis Crick  Institute (COVASE study)/ I-SPY COVID trial</div>, <div class="is_h5-2 is_developer w-richtext">Vicore Pharma</div>, <div class="is_h5-2 is_developer w-richtext">ViralClear Pharmaceuticals</div>, <div class="is_h5-2 is_developer w-richtext">Washington University School of Medicine in St. Louis/ Covid-19 Early Treatment Fund (CETF)</div>, <div class="is_h5-2 is_developer w-richtext">Zydus Cadila Group; The Camelot Foundation
# </div>, <div class="is_h5-2 is_developer w-richtext">Zydus Cadila/ Avant Sante Research Center</div>, <div class="is_h5-2 is_developer w-richtext">aTyr</div>, <div class="is_h5-2 is_developer w-richtext">ACTIV-5/BET-B  for COVID-19/National Institute of Allergy and Infectious Disease (NIAID)/Boehringer Ingelheim/AbbVie</div>, <div class="is_h5-2 is_developer w-richtext">BioIncept</div>, <div class="is_h5-2 is_developer w-richtext">Bioxytran</div>, <div class="is_h5-2 is_developer w-richtext">CEL-SCI / University of Georgia Center for Vaccines and Immunology</div>, <div class="is_h5-2 is_developer w-richtext">Chelation Partners</div>, <div class="is_h5-2 is_developer w-richtext">Hebrew University of Jerusalem/ University of Pennsylvania/ University Arizona </div>, <div class="is_h5-2 is_developer w-richtext">Lupa Bio, Inc.</div>, <div class="is_h5-2 is_developer w-richtext">Merck KGaA</div>, <div class="is_h5-2 is_developer w-richtext">Merck/ IRBM/ RaPharma</div>, <div class="is_h5-2 is_developer w-richtext">Moleculin Biotech/ University of Texas Medical Branch/ Sterling Pharma USA</div>, <div class="is_h5-2 is_developer w-richtext">NanoViricides/ TheraCour Pharma Inc.</div>, <div class="is_h5-2 is_developer w-richtext">National Institute of Allergy and Infectious Disease (NIAID)</div>, <div class="is_h5
div>, <div class="is_h5-2 is_developer w-richtext" id="w-node-aa5b35123335-d8371e24">OSE
#   Immunotherapeutics</div>, <div class="is_h5-2 is_developer w-richtext" id="w-node-aa5b35123335-d8371e24">Oragenics (Noachis Terra)/ Aragen Bioscience
# </div>, <div class="is_h5-2 is_developer w-richtext" id="w-node-aa5b35123335-d8371e24">NidoVax</div>, <div class="is_h5-2 is_developer w-richtext" id="w-node-aa5b35123335-d8371e24">Vault Pharma/ University of California Los Angeles</div>, <div class="is_h5-2 is_developer w-richtext" id="w-node-aa5b35123335-d8371e24">Tulane University</div>, <div class="is_h5-2 is_developer w-richtext" id="w-node-aa5b35123335-d8371e24">Catholic University/ Millennium Institute of Immunology and Immunotherapy/ Technological Consortium in Clinical Molecular Biomedicine, Chile</div>, <div class="is_h5-2 is_developer w-richtext" id="w-node-aa5b35123335-d8371e24">HaloVax (Voltron Therapeutics) / The Vaccine &amp; Immunotherapy Center at the Massachusetts General Hospital</div>, <div class="is_h5-2 is_developer w-richtext" id="w-node-aa5b35123335-d8371e24">Emergex Vaccines/ George Mason University's National Center for Biodefense and Infectious Diseases (NCBID)</div>, <div class="is_h5-2 is_developer w-richtext" id="w-node-aa5b35123335-d8371e24">Vivaldi Biosciences/ Esco Aster Pte Ltd</div>, <div class="is_h5-2 is_developer w-richtext" id="w-node-aa5b35123335-d8371e24">Adeleke University</div>, <div class="is_h5-2 is_developer w-richtext" id="w-node-aa5b35123335-d8371e24">AbVision</div>, <div class="is_h5-2 is_developer w-richtext" id="w-node-aa5b35123335-d8371e24">Codiak BioSciences/ Ragon Institute</div>, <div class="is_h5-2 is_developer w-richtext" id="w-node-aa5b35123335-d8371e24">Precision Vaccines Program at Boston Children's Hospital</div>, <div class="is_h5-2 is_developer w-richtext" id="w-node-aa5b35123335-d8371e24">Vir Biotechnology / GSK</div>, <div class="is_h5-2 is_developer w-richtext" id="w-node-aa5b35123335-d8371e24">ISR Immune System Regulation</div>]

# %%
print("NO 1 " + result[46:86]) 
print("NO 2 "+result[139:226]) 
print("NO 3 "+result[279:305]) 
print("NO 4 "+result[358:375]) 
print("NO 5 "+result[428:509])
# Out:
# NO 1 Alexion Pharmaceuticals. TACTIC-R trial
# NO 2 Assistance Publique - Hopitaux de Paris (Phase II); Alexion (Expanded Access Protocols)
# NO 3 AstraZeneca; ACCORD trial
# NO 4 BioCon/Equilium <
# NO 5 elltrion</div>, <div class="is_h5-2 is_developer w-richtext">Celltrion/ Universit

# %%
for i in range(20):
    print(f"NO {i} :" +result[46:86])
# Out:
# NO 0 :Alexion Pharmaceuticals. TACTIC-R trial
# NO 1 :Alexion Pharmaceuticals. TACTIC-R trial
# NO 2 :Alexion Pharmaceuticals. TACTIC-R trial
# NO 3 :Alexion Pharmaceuticals. TACTIC-R trial
# NO 4 :Alexion Pharmaceuticals. TACTIC-R trial
# NO 5 :Alexion Pharmaceuticals. TACTIC-R trial
# NO 6 :Alexion Pharmaceuticals. TACTIC-R trial
# NO 7 :Alexion Pharmaceuticals. TACTIC-R trial
# NO 8 :Alexion Pharmaceuticals. TACTIC-R trial
# NO 9 :Alexion Pharmaceuticals. TACTIC-R trial
# NO 10 :Alexion Pharmaceuticals. TACTIC-R trial
# NO 11 :Alexion Pharmaceuticals. TACTIC-R trial
# NO 12 :Alexion Pharmaceuticals. TACTIC-R trial
# NO 13 :Alexion Pharmaceuticals. TACTIC-R trial
# NO 14 :Alexion Pharmaceuticals. TACTIC-R trial
# NO 15 :Alexion Pharmaceuticals. TACTIC-R trial
# NO 16 :Alexion Pharmaceuticals. TACTIC-R trial
# NO 17 :Alexion Pharmaceuticals. TACTIC-R trial
# NO 18 :Alexion Pharmaceuticals. TACTIC-R trial
# NO 19 :Alexion Pharmaceuticals. TACTIC-R trial
